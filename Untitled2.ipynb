# %%
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'svg')

from cmonkeyobj import cMonkey2 as cm2
b = cm2('eco-out-001/cmonkey_run.db')
# Out:
# iteration = 2001

# %%
import pandas as pd
pd.options.display.mpl_style = 'default'

from mpltools import style
from mpltools import layout

style.use('ggplot')

# %%
b.tables['run_infos']
# Out:
#                    start_time                 finish_time  num_iterations  \
# 0  2014-10-23 15:03:07.507436  2014-10-24 15:08:15.758689            2000
#
#    last_iteration organism               species  num_rows  num_columns  \
# 0            2000      eco  Escherichia_coli_K12      4297          176
#
#    num_clusters                                          git_sha
# 0           203  $Id: 0ce7c2ec595690a34f278241f17eb6749af9c6a9 $

# %%
b.plot_motif(10,1)
# Out:
# <module 'matplotlib.pyplot' from '/home/dreiss/python/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>

# %%
b.get_cluster_info(10)
# Out:
# {'e_values': array([  6.50000000e+00,   8.70000000e+04]),
#  'ncols': 176,
#  'nrows': 36,
#  'pclusts': array([-5.64858733, -9.59647926]),
#  'residual': 0.4382560429620751}

# %%
sites = b.get_motif_sites(10, 1)
sites
# Out:
# 19
#      reverse  start        pvalue  flank_left             seq flank_right  \
# 1          0     47  1.080000e-08  TTATTTGCCC  GTCAGCCAGCAAAA  ATCCACAAAC
# 13         0     34  1.350000e-07  GTACCACGCA  GTAACCCTGCAAAA  TAGCCAATAA
# 25         0     53  4.010000e-07  AAAAGAAGTT  GTAACACTGCAAAA  TCCTGCTATT
# 33         1     92  4.010000e-07  CAGTACACAG  GTTAACCAGCAAAA  GGATTTGTCA
# 44         0     80  1.100000e-06  GATAACAAAC  ATCAACCTGCAAAA  CGAAGCGCAT
# 55         1    117  3.130000e-06  CTTTTTTGTC  GTTAGCCAGCAAGA  GCCGTTTACT
# 66         1     43  3.740000e-06  CATAACTGCC  GTCAATGCGCAAAA  TTCACGCCAC
# 77         0    157  4.120000e-06  CAGCNNNNTC  GAAAGTCTGCATAA        None
# 88         1     69  4.540000e-06  TAATACGAAT  GAATGAGAGCAAAA  GCGGGAAATA
# 99         0      8  7.970000e-06     ATAACTT  GTCACATTGCAAAA  GTAGCCAAAT
# 110        0     47  1.140000e-05  ATTTATATAT  ATTTATCTGCAAAA  TTTTAAATAA
# 121        1    100  1.300000e-05  TGCCTGGATA  GAATGAGTGCATAA  CAAACTATAG
# 132        0     92  1.380000e-05  AACTCCCGTC  AGTTGCGAGCAAAA  AAGCCGCTAC
# 143        0    100  1.380000e-05  AAAAATGTCC  GGAAGACACCAAAA  AGTTGTCGCA
# 154        1     14  1.470000e-05  ACGGGCGGTA  ATCAGTGCGCATAA  AATAAGGATG
#
#               id  names
# 1    NP_415842.1  b1326
# 13   NP_415273.1  b0752
# 25         b4581  b4581
# 33   NP_415971.1  b1454
# 44   NP_415605.2  b1087
# 55   NP_416480.1  b1971
# 66   NP_415473.1  b0953
# 77   NP_415488.1  b0968
# 88   NP_415485.4  b0965
# 99   NP_415113.1  b0581
# 110  NP_416239.1  b1725
# 121  NP_416615.1  b2112
# 132  NP_416849.1  b2347
# 143  NP_415736.2  b1218
# 154  NP_416115.1  b1598

# %%
b.get_motif_pclust(10,1)
# Out:
# -5.6485873336261481

# %%
b.ratios = None
b.load_ratios()
b.plot_ratios(10)

# %%
b.plot_ratios(10,kind='box')

# %%
## see http://pandas.pydata.org/pandas-docs/version/0.15.0/visualization.html#histograms
pd.Series([b.get_cluster_info(k)['residual'] for k in range(1,b.k_clust)]).plot(kind='hist',bins=20)

# %%
pd.DataFrame([b.get_cluster_info(k)['pclusts'] for k in range(1,b.k_clust)]).plot(kind='hist',bins=20,stacked=True)

# %%
b.plot_cluster_networks(10)

# %%
## Note this is a work in progress!!!
img=b.plot_motif_sites(10,1)
# Out:
# 19
