# %%
from cmonkeyobj import cMonkey2 as cm2
b = cm2('eco-test/cmonkey_run.db')
# Out:
# iteration = 470

# %%
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'svg')

# %%
b.reload()
b.stats = None
b.plot_stats()
# Out:
# iteration = 2001

# %%
## note can do this to save to vectorized svg:
plt.savefig('out.svg', transparent = True)

# %%
b.clusters_w_genes('b0032')
# Out:
#    cluster   name
# 0      219  b0032
# 1      273  b0032

# %%
b.plot_motif(273,1)
# Out:
# <module 'matplotlib.pyplot' from '/home/dreiss/python/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>

# %%
b.plot_motif(140,1)
# Out:
# <module 'matplotlib.pyplot' from '/home/dreiss/python/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>
